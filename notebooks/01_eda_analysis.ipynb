# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Загружаем датасет
df = pd.read_csv('../data/raw/gastric_cancer_detection_dataset.csv')

# Показываем первые 5 строк
df.head()
# Out:
#    age  gender    ethnicity geographical_location  family_history  \
# 0   43    Male  Ethnicity_A                 Other               1
# 1   86  Female  Ethnicity_B            California               1
# 2   68    Male  Ethnicity_A            California               0
# 3   57  Female  Ethnicity_A                 Other               0
# 4   33    Male  Ethnicity_A            California               0
#
#    smoking_habits  alcohol_consumption  helicobacter_pylori_infection  \
# 0               0                    0                              0
# 1               0                    0                              1
# 2               1                    1                              0
# 3               0                    0                              1
# 4               1                    1                              0
#
#   dietary_habits existing_conditions  ...     elmmo microcosm   miranda  \
# 0       Low_Salt   Chronic Gastritis  ...  0.187003  0.786422  0.204816
# 1      High_Salt            Diabetes  ...  0.493322  0.963989  0.498041
# 2      High_Salt                 NaN  ...  0.573560  0.666896  0.540388
# 3      High_Salt   Chronic Gastritis  ...  0.261399  0.949488  0.134170
# 4      High_Salt            Diabetes  ...  0.754478  0.263164  0.876767
#
#       mirdb    pictar      pita  targetscan  predicted.sum   all.sum  label
# 0  0.561920  0.438175  0.283603    0.928244       4.324299  7.666791      0
# 1  0.985585  0.144609  0.375375    0.103573       7.967674  1.483280      0
# 2  0.905853  0.827279  0.350915    0.166878       3.748651  3.046783      0
# 3  0.429935  0.935231  0.794704    0.867036       5.478298  8.811307      0
# 4  0.650832  0.337669  0.427492    0.915804       1.809181  0.394632      0
#
# [5 rows x 29 columns]

# %%
# !pip install pandas numpy matplotlib seaborn
# Out:
# Collecting pandas
#   Downloading pandas-3.0.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting numpy
#   Downloading numpy-2.5.0-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.11.0-cp313-cp313-win_amd64.whl.metadata (80 kB)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\appol\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\appol\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2026.2)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.63.0-cp313-cp313-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in C:\Users\appol\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (26.2)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.3.0-cp313-cp313-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in C:\Users\appol\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.3-cp313-cp313-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.8 MB 6.7 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/9.8 MB 5.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.9/9.8 MB 6.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.8/9.8 MB 7.2 MB/s eta 0:00:01
#    ------------------------------- -------- 7.6/9.8 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.8 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 7.5 MB/s  0:00:01
# Downloading numpy-2.5.0-cp313-cp313-win_amd64.whl (12.4 MB)
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ----- ---------------------------------- 1.8/12.4 MB 10.3 MB/s eta 0:00:02
#    ------------ --------------------------- 3.9/12.4 MB 9.4 MB/s eta 0:00:01
#    ------------------- -------------------- 6.0/12.4 MB 9.6 MB/s eta 0:00:01
#    --------------------------- ------------ 8.4/12.4 MB 9.7 MB/s eta 0:00:01
#    -------------------------------- ------- 10.2/12.4 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.4 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 9.3 MB/s  0:00:01
# Downloading matplotlib-3.11.0-cp313-cp313-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    -------- ------------------------------- 2.1/9.3 MB 9.9 MB/s eta 0:00:01
#    ------------------- -------------------- 4.5/9.3 MB 10.3 MB/s eta 0:00:01
#    -------------------------- ------------- 6.3/9.3 MB 10.4 MB/s eta 0:00:01
#    ------------------------------------- -- 8.7/9.3 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 9.4 MB/s  0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp313-cp313-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ----------------------------------- ---- 2.1/2.3 MB 10.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 9.6 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp313-cp313-win_amd64.whl (73 kB)
# Downloading pillow-12.3.0-cp313-cp313-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ----------- ---------------------------- 2.1/7.2 MB 10.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.2/7.2 MB 10.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.3/7.2 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 9.5 MB/s  0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, pandas, contourpy, matplotlib, seaborn
#
#    ----------------------------------------  0/10 [pyparsing]
#    ---- -----------------------------------  1/10 [pillow]
#    ---- -----------------------------------  1/10 [pillow]
#    ---- -----------------------------------  1/10 [pillow]
#    ---- -----------------------------------  1/10 [pillow]
#    ---- -----------------------------------  1/10 [pillow]
#    ---- -----------------------------------  1/10 [pillow]
#    ---- -----------------------------------  1/10 [pillow]
#    ---- -----------------------------------  1/10 [pillow]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ---------------- -----------------------  4/10 [fonttools]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ---------------------------- -----------  7/10 [contourpy]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    -------------------------------- -------  8/10 [matplotlib]
#    ------------------------------------ ---  9/10 [seaborn]
#    ------------------------------------ ---  9/10 [seaborn]
#    ------------------------------------ ---  9/10 [seaborn]
#    ------------------------------------ ---  9/10 [seaborn]
#    ------------------------------------ ---  9/10 [seaborn]
#    ---------------------------------------- 10/10 [seaborn]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.0 numpy-2.5.0 pandas-3.0.3 pillow-12.3.0 pyparsing-3.3.2 seaborn-0.13.2
